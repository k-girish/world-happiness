# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def has_duplicates(x):
    return len(x) > len(x.unique())

def view_all_df(temp):
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        display(temp)
        
def create_rename_dict_from_list(rlist):
    rename_dict = {}
    for l,n in rlist:
        for e in l:
            rename_dict[e]=n
    return rename_dict

# %%
# Unofficial
rename_list = [(['Country name',
 'Country or region'], 'Country'),
(['Dystopia + residual',
 'Dystopia Residual',
 'Dystopia.Residual'], 'Dystopia Residual'),
(['Economy (GDP per Capita)',
 'Economy..GDP.per.Capita.',], 'GDP per capita'),
(['Happiness.Rank'], 'Happiness Rank'),
(['Happiness.Score'], 'Happiness Score'),
(['Health (Life Expectancy)',
 'Health..Life.Expectancy.',
 'Healthy life expectancy',], 'Life Expectancy'),
# (['Ladder score in Dystopia'], 'Ladder score'),
(['Trust..Government.Corruption.'], 'Trust (Government Corruption)'),
(['Whisker.high'], 'upperwhisker'),
(['Whisker.low'], 'lowerwhisker')
]

# Official
rename_list=[
(['GINI index (World Bank estimate)',
 'GINI index (World Bank estimate), average 2000-13',
 'GINI index (World Bank estimate), average 2000-15',
 'GINI index (World Bank estimate), average 2000-16',
 'gini of household income reported in Gallup, by wp5-year'], 'GINI index'),
(['Healthy life expectancy at birth'], 'Healthy life expectancy'),
(['Logged GDP per capita'], 'Log GDP per capita'),
([
 'Most people can be trusted, Gallup',
 'Most people can be trusted, WVS round 1981-1984',
 'Most people can be trusted, WVS round 1989-1993',
 'Most people can be trusted, WVS round 1994-1998',
 'Most people can be trusted, WVS round 1999-2004',
 'Most people can be trusted, WVS round 2005-2009',
 'Most people can be trusted, WVS round 2010-2014',], 'Most people can be trusted'),
([
 'Standard deviation of ladder by country-year',
 'Standard deviation/Mean of ladder by country-year',
 'Standard error of ladder score'], 'Standard deviation of ladder')
]

# %% [markdown]
# ## Official

# %%
df = pd.read_csv('../data/2021.csv')
df.loc[:, 'report_year'] = 2021
for year in range(2015, 2020):
    temp = pd.read_csv(f'../data/{year}.csv')
    temp.loc[:, 'report_year'] = year
    df = pd.concat([df, temp], ignore_index=True)
df = df.sort_values(by=['Country name', 'report_year']).reset_index(drop=True)
df
# Out:
#     Country name                  Regional indicator  Ladder score  \
# 0    Afghanistan                          South Asia         2.523
# 1        Albania          Central and Eastern Europe         5.117
# 2        Algeria        Middle East and North Africa         4.887
# 3      Argentina         Latin America and Caribbean         5.929
# 4        Armenia  Commonwealth of Independent States         5.283
# ..           ...                                 ...           ...
# 926          NaN                                 NaN           NaN
# 927          NaN                                 NaN           NaN
# 928          NaN                                 NaN           NaN
# 929          NaN                                 NaN           NaN
# 930          NaN                                 NaN           NaN
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.038         2.596         2.449
# ...

# %%
sorted(df.columns)
# Out:
# ['Country',
#  'Country name',
#  'Country or region',
#  'Dystopia + residual',
#  'Dystopia Residual',
#  'Dystopia.Residual',
#  'Economy (GDP per Capita)',
#  'Economy..GDP.per.Capita.',
#  'Explained by: Freedom to make life choices',
#  'Explained by: Generosity',
#  'Explained by: Healthy life expectancy',
#  'Explained by: Log GDP per capita',
#  'Explained by: Perceptions of corruption',
#  'Explained by: Social support',
#  'Family',
#  'Freedom',
#  'Freedom to make life choices',
#  'GDP per capita',
#  'Generosity',
#  'Happiness Rank',
#  'Happiness Score',
#  'Happiness.Rank',
#  'Happiness.Score',
#  'Health (Life Expectancy)',
#  'Health..Life.Expectancy.',
#  'Healthy life expectancy',
#  'Ladder score',
#  'Ladder score in Dystopia',
#  'Logged GDP per capita',
#  'Lower Confidence Interval',
#  'Overall rank',
#  'Perceptions of corruption',
#  'Region',
#  'Regional indicator',
#  'Score',
#  'Social support',
#  'Standard Error',
# ...

# %%
df[df['Country name']=='United States'].shape
# Out:
# (15, 47)

# %%
view_all_df(df[df['Country name']=='United States'])
# Out:
#        Country name     Regional indicator  Ladder score  \
# 1890  United States                    NaN           NaN
# 1891  United States                    NaN           NaN
# 1892  United States                    NaN           NaN
# 1893  United States                    NaN           NaN
# 1894  United States                    NaN           NaN
# 1895  United States                    NaN           NaN
# 1896  United States                    NaN           NaN
# 1897  United States                    NaN           NaN
# 1898  United States                    NaN           NaN
# 1899  United States                    NaN           NaN
# 1900  United States                    NaN           NaN
# 1901  United States                    NaN           NaN
# 1902  United States                    NaN           NaN
# 1903  United States  North America and ANZ        6.9396
# 1904  United States  North America and ANZ        6.9510
#
# ...

# %%
df = pd.read_csv('../data/2021.csv')

# %%
df
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
df = pd.read_csv('../data/official/2015_changes.csv')
df
# Out:
#           WP5 Country       country  Changes in ladder scores  \
# 0       158 Nicaragua     Nicaragua                  1.121140
# 1        081 Zimbabwe      Zimbabwe                  1.055892
# 2         115 Ecuador       Ecuador                  0.965203
# 3         075 Moldova       Moldova                  0.950220
# 4    080 Sierra Leone  Sierra Leone                  0.900512
# ..                ...           ...                       ...
# 120        065 Rwanda        Rwanda                 -0.749665
# 121  005 Saudi Arabia  Saudi Arabia                 -0.761579
# 122         018 Italy         Italy                 -0.764193
# 123         002 Egypt         Egypt                 -1.231222
# 124        024 Greece        Greece                 -1.469236
#
#      Standard error of changes in ladder scores  Changes in: GDP per capita  \
# 0                                      0.093747                    0.116755
# ...
